# %% [markdown]
# # Using Natural Language Processing on News articles to find the sentiment of the news realted to Gold

# %% [markdown]
# **Data 602 : Intro to Data Analysis and Machine Learning**
#
# **Professor:** Dr. Antonio Diana

# %% [markdown]
# **Team:**
#
#
# *   Hariom Vyas
# *   Krutal Patel
# *   Viral Jani
# *   Durga Siva Sai Verma Rudraraju

# %% [markdown]
# Here we are using multipple techniques to find news related to gold on internet. We are using packages like NewsCatcher to go through websites like Guardian and finding if they have any top news related to gold on them to stay updated on latest trend.
#
# We are using Google news to find recent top news on gold.
#
# After that we are using BeautifulSoup and request to go through diffrent articles and doing sentiment analysis on them. We are doing sentiment analysis using multiple ways.
#
#
# *   Textblob
# *   Pattern
#
# We are generating word cloud for all the news for visualizing unstructured text data and getting insights on trends and patterns.

# %% [markdown]
# ## Installing required packages and dependancies

# %%
# !pip install pattern
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pattern
#   Downloading Pattern-3.6.0.tar.gz (22.2 MB)
#      |████████████████████████████████| 22.2 MB 17.4 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from pattern) (0.16.0)
# Collecting backports.csv
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.1.1.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 6.8 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from pattern) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pattern) (4.9.1)
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 4.2 MB/s
# Collecting pdfminer.six
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 37.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pattern) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pattern) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from pattern) (3.7)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 36.3 MB/s
# Collecting cherrypy
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      |████████████████████████████████| 348 kB 43.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from pattern) (2.23.0)
# Collecting portend>=2.1.1
#   Downloading portend-3.1.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern) (9.0.0)
# Collecting jaraco.collections
#   Downloading jaraco.collections-3.8.0-py3-none-any.whl (10 kB)
# Collecting cheroot>=8.2.1
#   Downloading cheroot-9.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 8.8 MB/s
# Collecting zc.lockfile
#   Downloading zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.5.2-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from cheroot>=8.2.1->cherrypy->pattern) (1.15.0)
# Collecting tempora>=1.8
#   Downloading tempora-5.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2022.6)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Collecting jaraco.text
#   Downloading jaraco.text-3.11.0-py3-none-any.whl (11 kB)
# Collecting autocommand
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Collecting jaraco.context>=4.1
#   Downloading jaraco.context-4.2.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (5.10.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->jaraco.text->jaraco.collections->cherrypy->pattern) (3.11.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (2022.6.2)
# Collecting cryptography>=36.0.0
#   Downloading cryptography-38.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 39.3 MB/s
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (1.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from zc.lockfile->cherrypy->pattern) (57.4.0)
# Building wheels for collected packages: pattern, mysqlclient, python-docx, sgmllib3k
#   Building wheel for pattern (setup.py) ... done
#   Created wheel for pattern: filename=Pattern-3.6-py3-none-any.whl size=22332722 sha256=ee36be0eb78365eb64a7bd87807d77c83d2cb973915257c4302ddb28c3f4fbe5
#   Stored in directory: /root/.cache/pip/wheels/ec/ce/8f/bccc2d04f3a25a5a1dd19165b2855ad3203975f25edd5838d6
#   Building wheel for mysqlclient (setup.py) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.1.1-cp38-cp38-linux_x86_64.whl size=102410 sha256=3747a1537efd866e48f4af71d159b4508ff6e0b5d283247fbdd9434ee6ffc5dd
#   Stored in directory: /root/.cache/pip/wheels/5b/e1/84/a6185eaec318899f59a32d393af7729a0719cd93695d71f9a1
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184505 sha256=5668e327223d6bc5573e4939fa276d855f58457d149229990d2c1dd1a58e2727
#   Stored in directory: /root/.cache/pip/wheels/32/b8/b2/c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=79458150fb16ce10f3c6e84a83054fd4d18b871ba6b3debd215466c5c826d6b8
#   Stored in directory: /root/.cache/pip/wheels/83/63/2f/117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built pattern mysqlclient python-docx sgmllib3k
# Installing collected packages: jaraco.functools, jaraco.context, autocommand, tempora, jaraco.text, jaraco.classes, zc.lockfile, sgmllib3k, portend, jaraco.collections, cryptography, cheroot, python-docx, pdfminer.six, mysqlclient, feedparser, cherrypy, backports.csv, pattern
# Successfully installed autocommand-2.2.2 backports.csv-1.0.7 cheroot-9.0.0 cherrypy-18.8.0 cryptography-38.0.4 feedparser-6.0.10 jaraco.classes-3.2.3 jaraco.collections-3.8.0 jaraco.context-4.2.0 jaraco.functools-3.5.2 jaraco.text-3.11.0 mysqlclient-2.1.1 pattern-3.6 pdfminer.six-20221105 portend-3.1.0 python-docx-0.8.11 sgmllib3k-1.0.0 tempora-5.1.0 zc.lockfile-2.0

# %%
# !pip install pygooglenews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygooglenews
#   Downloading pygooglenews-0.1.2-py3-none-any.whl (10 kB)
# Collecting dateparser<0.8.0,>=0.7.6
#   Downloading dateparser-0.7.6-py2.py3-none-any.whl (362 kB)
#      |████████████████████████████████| 362 kB 7.1 MB/s
# Collecting requests<3.0.0,>=2.24.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Collecting feedparser<6.0.0,>=5.2.1
#   Downloading feedparser-5.2.1.zip (1.2 MB)
#      |████████████████████████████████| 1.2 MB 28.7 MB/s
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 41.3 MB/s
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.6)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.6.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (1.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.15.0)
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44951 sha256=d6e8b4918338a732b76c52abf89cbba9dabcf1758b148deb6b804ebb30d392cd
#   Stored in directory: /root/.cache/pip/wheels/67/38/07/59c89c3d334e7f1f743898af6d21c15ecb3588ad04af7ddee0
# Successfully built feedparser
# Installing collected packages: soupsieve, requests, feedparser, dateparser, beautifulsoup4, pygooglenews
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: feedparser
#     Found existing installation: feedparser 6.0.10
#     Uninstalling feedparser-6.0.10:
#       Successfully uninstalled feedparser-6.0.10
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.1 dateparser-0.7.6 feedparser-5.2.1 pygooglenews-0.1.2 requests-2.28.1 soupsieve-2.3.2.post1

# %%
# !pip install newscatcher
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting newscatcher
#   Downloading newscatcher-0.2.0-py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 7.7 MB/s
# Requirement already satisfied: feedparser<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from newscatcher) (5.2.1)
# Collecting tldextract<3.0.0,>=2.2.2
#   Downloading tldextract-2.2.3-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 5.2 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from newscatcher) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (2.1.1)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from requests-file>=1.4->tldextract<3.0.0,>=2.2.2->newscatcher) (1.15.0)
# Installing collected packages: requests-file, tldextract, newscatcher
# Successfully installed newscatcher-0.2.0 requests-file-1.5.1 tldextract-2.2.3

# %%
# Imprting required libraries

import requests
import nltk
from bs4 import BeautifulSoup
import urllib.request,sys,time
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import random
from wordcloud import WordCloud
import os
import spacy
nlp = spacy.load('en_core_web_sm')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('stopwords')
from textblob import TextBlob
from pattern.en import sentiment
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## News from NewsCatcher

# %%
from newscatcher import Newscatcher, describe_url

newcatcher_news = []

mm = Newscatcher(website = 'https://www.theguardian.com/us')

for index, headline in enumerate(mm.get_headlines()):
   newcatcher_news.append(headline)
  
print(newcatcher_news)
# Out:
# ['Twitter relaunches blue tick service with higher price for iPhone users', 'FTX’s Sam Bankman-Fried to testify before Congress next week', 'How do we make sense of changing human social norms? Ask a bot, of course | Torsten Bell', 'ChatGPT can tell jokes, even write articles. But only humans can detect its fluent bullshit | Kenan Malik', 'Elon Musk could lose world’s richest person title as Tesla value almost halves', 'I wrote this column myself, but how long before a chatbot could do it for me? | John Naughton', 'Crowd boos Elon Musk after Dave Chappelle says to ‘make some noise’', 'Bankman-Fried ‘would give anything’ to start new business to repay FTX users', 'Elon Musk accused of turning Twitter offices into bedrooms', 'Texas bans TikTok on government devices amid China data-sharing fears', 'No safe haven? The Bahraini dissident still menaced after gaining UK asylum', 'Risky online behaviour ‘almost normalised’ among young people, says study', 'Is it worth taking out personal cyber insurance in case you are caught up in a data hack?', 'Pegasus spyware inquiry targeted by disinformation campaign, say experts', 'Amazon has delivered £3,500-worth of the same cookbook', 'Mobiles are ‘potential goldmines’ for hostile states, MPs warned', 'Australian companies don’t value keeping our data safe because they have little to lose. Our laws need to change that | George Newhouse and Duncan Fine', 'Medibank: how hackers got your private health data', 'What was Dracula really like? 550-year-old clue to life of Vlad the Impaler emerges', 'After years of fanfare the future of drone delivery in Australia remains up in the air', 'Blinded by the light: how skyglow pollution is separating us from the stars', 'Is this the end of TV? Broadcasters prepare for online-only switch', 'Longtermism: how good intentions and the rich created a dangerous creed', 'The death of Twitter has dragged on too long. Please, Elon, put us out of our misery | Jack Vening', 'Changes to online safety bill tread line between safety and appearing ‘woke’', 'Crypto will survive the FTX collapse – but more scandals will follow | Kenneth Rogoff', 'The Guide #64: Six games the whole family will enjoy this Christmas', 'The Game awards: three patience-testing hours of video game advertorials', 'US agency moves to block landmark merger of Microsoft and Activision Blizzard', 'Unsocial hours: the best video games to play in ‘goblin mode’', 'Pushing Buttons: The one game my kid will play with me', 'Infinite lives: the company saving old arcade machines', 'Sam Bankman-Fried’s fall hasn’t killed off ‘effective altruism’ | Brief letters', 'The gods of Silicon Valley are falling to earth. So are their warped visions for society | Moya Lothian-McLean', 'Power-hungry robots, space colonization, cyborgs: inside the bizarre world of ‘longtermism’', 'Major investor calls on Google owner to ‘aggressively’ cut staff and pay', 'Sky Stream review: the satellite-free Sky TV streaming box', 'Apple TV 4K 2022 review: cheaper but still premium streaming box', 'Microsoft Surface Laptop 5 review: slick operation but dated design', 'Access All Areas review – brave family’s quest to change attitudes to disability', 'iPhone 14 Plus review: Apple’s big-screen battery champ', 'The Secret Genius of Modern Life review – irresistibly contagious TV', 'Zombiegate review – a Halloween night dive into online toxicity', 'Apple Watch Ultra review: the super-charged smartwatch', 'Alexa, how did Amazon’s wrong call on voice assistants tee up a $10bn loss? | John Naughton', 'Two fluffy lambs playing Twister: Kieran Dodds’ best phone picture', 'TechScape: Meet ChatGPT, the viral AI tool that may be a vision of our weird tech future', 'Going, going gone: how Made, millennials’ favourite sofa-maker, wound up under the hammer', '‘The most effective press watchdog’: Owen Jones, Arwa Mahdawi and more on how Twitter changed journalism', 'What will happen next for Black Twitter?', 'TechScape: Enter the multiverse – the cha ...

# %%
newsdf = pd.DataFrame(newcatcher_news)
newsdf.to_excel("NewsCatcher.xlsx")

# %%
cloud_words = ""

for val in newcatcher_news:
  val = str(val)
  tokens = val.split()
  for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
  cloud_words += " ".join(tokens)+" "

# %%
# Plotting Word Cloud

plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(cloud_words)
plt.imshow(wordcloud)
plt.title('NEWS ARTICLE (100 words)')
plt.axis('off')
plt.show()

# %%
cloud_words
# Out:
# 'twitter relaunches blue tick service with higher price for iphone users ftx’s sam bankman-fried to testify before congress next week how do we make sense of changing human social norms? ask a bot, of course | torsten bell chatgpt can tell jokes, even write articles. but only humans can detect its fluent bullshit | kenan malik elon musk could lose world’s richest person title as tesla value almost halves i wrote this column myself, but how long before a chatbot could do it for me? | john naughton crowd boos elon musk after dave chappelle says to ‘make some noise’ bankman-fried ‘would give anything’ to start new business to repay ftx users elon musk accused of turning twitter offices into bedrooms texas bans tiktok on government devices amid china data-sharing fears no safe haven? the bahraini dissident still menaced after gaining uk asylum risky online behaviour ‘almost normalised’ among young people, says study is it worth taking out personal cyber insurance in case you are caught up in a data hack? pegasus spyware inquiry targeted by disinformation campaign, say experts amazon has delivered £3,500-worth of the same cookbook mobiles are ‘potential goldmines’ for hostile states, mps warned australian companies don’t value keeping our data safe because they have little to lose. our laws need to change that | george newhouse and duncan fine medibank: how hackers got your private health data what was dracula really like? 550-year-old clue to life of vlad the impaler emerges after years of fanfare the future of drone delivery in australia remains up in the air blinded by the light: how skyglow pollution is separating us from the stars is this the end of tv? broadcasters prepare for online-only switch longtermism: how good intentions and the rich created a dangerous creed the death of twitter has dragged on too long. please, elon, put us out of our misery | jack vening changes to online safety bill tread line between safety and appearing ‘woke’ crypto will survive the ftx collapse – but more scandals will follow | kenneth rogoff the guide #64: six games the whole family will enjoy this christmas the game awards: three patience-testing hours of video game advertorials us agency moves to block landmark merger of microsoft and activision blizzard unsocial hours: the best video games to play in ‘goblin mode’ pushing buttons: the one game my kid will play with me infinite lives: the company saving old arcade machines sam bankman-fried’s fall hasn’t killed off ‘effective altruism’ | brief letters the gods of silicon valley are falling to earth. so are their warped visions for society | moya lothian-mclean power-hungry robots, space colonization, cyborgs: inside the bizarre world of ‘longtermism’ major investor calls on google owner to ‘aggressively’ cut staff and pay sky stream review: the satellite-free sky tv streaming box apple tv 4k 2022 review: cheaper but still premium streaming box microsoft surface laptop 5 review: slick operation but dated design access all areas review – brave family’s quest to change attitudes to disability iphone 14 plus review: apple’s big-screen battery champ the secret genius of modern life review – irresistibly contagious tv zombiegate review – a halloween night dive into online toxicity apple watch ultra review: the super-charged smartwatch alexa, how did amazon’s wrong call on voice assistants tee up a $10bn loss? | john naughton two fluffy lambs playing twister: kieran dodds’ best phone picture techscape: meet chatgpt, the viral ai tool that may be a vision of our weird tech future going, going gone: how made, millennials’ favourite sofa-maker, wound up under the hammer ‘the most effective press watchdog’: owen jones, arwa mahdawi and more on how twitter changed journalism what will happen next for black twitter? techscape: enter the multiverse – the chat-room game made of ai art '

# %% [markdown]
# ## News from Google News

# %%
from pygooglenews import GoogleNews

google_news = []

gn = GoogleNews()
s = gn.search('gold')

for entry in s["entries"]:
    google_news.append(entry["title"])

print(google_news)
# Out:
# ['Gold ticks lower ahead of U.S. inflation data, Fed outcome - CNBC', 'How to invest in gold for beginners - CBS News', 'A nano-thin layer of gold could prevent fogged-up glasses - Yahoo Finance', 'India gold seizures hit three-year high after import duty increase - Reuters.com', 'Gold is better portfolio diversifier than bitcoin -Goldman Sachs - Reuters.com', 'Deutsche Bank wants back in the gold market after eight-year absence - Kitco NEWS', "Gold miners' costs rise again in Q3'22 but the rate of increase has slowed - World Gold Council", 'Ascot arranges C$200 million financing for construction of the Premier gold project - Kitco NEWS', 'Twitter launches Blue for Business, grants gold checkmarks to ‘corporate entities’ - TechCrunch', 'US November CPI Preview: Gold is the asset to watch - FXStreet', 'Southern Empire Options Centauro Gold Project, Chihuahua, México; Starts Field Exploration Programs - AccessWire', 'Gold rates today fall from 9-month highs, silver prices drop | Mint - Mint', "There's a barrage of central bank decisions this week but gold investors need to watch two of them - Kitco NEWS", 'Gold retreats from near 4-month peak on positive U.S. jobs data - CNBC', 'Pants pulled from 1857 "Ship of Gold" shipwreck sell for $114,000 - CBS News', 'Gold Vs. Oil In 2023 - Seeking Alpha', 'Canex Announces Drilling Results and Westgold Target Expansion Gold Range Project, Arizona - AccessWire', 'Gold flat as dollar rises - CNBC', 'How six fighters could hold the UFC light heavyweight gold in 2023 - ESPN', 'Man facing charges for pawning stolen gold coins - KOLN', 'TRX Gold Releases Positive Metallurgical Drill Hole Assay Results - GlobeNewswire', 'Can Barrick Gold Corp (GOLD) Stock Rise to the Top of Basic Materials Sector Monday? - InvestorsObserver', "Deals: Anker's New Gold Box Sale on Amazon Has Up to 50% Off Charging Accessories - MacRumors", 'Kelly Zone: Channel 20 Returns 1.04 G/T Gold Across 13 Metres at the Wayka Project - AccessWire', 'Gold near three-month high on latest Russia jitters - CNBC', 'Recycled gold in old SIM cards could help create more sustainable medications - Study Finds', 'Kinross Gold: Tasiast To Deliver Record Production In 4Q22 (TSX:K:CA) - Seeking Alpha', 'First Mining Gold Sells Royalty in Ontario Gold Project for C$9.5M - MarketWatch', "Gold steadies as bargain hunters see off dollar's advance - CNBC", 'Price Disconnect In Physical Vs. Paper Gold - Investing.com', 'Iran Smuggling Venezuelan Gold To Finance Hezbollah: Document - ایران اینترنشنال', 'Senator Markey Applauds Passage of Legislation Awarding Congressional Gold Medal to Heroes Doherty, Woods, Stevens, and Smith Killed in 2012 Benghazi Consulate Attack - Ed Markey', 'How much is gold worth? - CBS News', 'Oil Volatile, Gold Nears Key Resistance - Investing.com', 'Gold Fields (GFI) Shares Cross Below 200 DMA - Nasdaq', '13 Best Gold Stocks To Buy For Recession - Yahoo Finance', "Early Drilling Intersects High-Grade Gold Within 20 Meters of Surface, 9.82 g/t Gold Intersected over 9.75 Meters at McFarlane Lake Mining's High Lake Property - Yahoo Finance", 'Delaware State Police Issue Gold Alert for Missing Newark Man - Delaware State Police - State of Delaware - Delaware.gov', "Chesser updates Senegal gold project economics - Creamer Media's Mining Weekly", "METALLA ADDS ROYALTIES ON BARRICK GOLD'S WORLD CLASS LAMA COMPLEX - Yahoo Finance", 'WCU Track Alum Manteo Mitchell Strikes Gold on the Ice - Western Carolina University - catamountsports.com', 'Avino Silver & Gold Mines Ltd (ASM) Is the Top Stock in the Other Precious Metals & Mining Industry? - InvestorsObserver', 'Proactive news headlines including Flynn Gold, Celsius Resources, Galileo Mining and NickelSearch - Yahoo Finance', 'Three Picks for a Gold Pullback - Moneyshow.com', 'Gold has a path to $2000 and silver to $25 in the second half of 2023 - Bank of America - Kitco NEWS', 'Black and Gold and Joy All Around: Three VCU team members reflect on their reasons for giving - VCU ...

# %%
newsdf = pd.DataFrame(google_news)
newsdf.to_excel("GoogleNews.xlsx")

# %%
cloud_words = ""

for val in google_news:
  val = str(val)
  tokens = val.split()
  for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
  cloud_words += " ".join(tokens)+" "

# %%
# Plotting Word Cloud

plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(cloud_words)
plt.imshow(wordcloud)
plt.title('NEWS ARTICLE (100 words)')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Part 1: Web Scraping the Articles

# %%
# Getting news articles using get from request packagge

r=requests.get('https://www.kitco.com/news/2022-12-02/Sentiment-shows-gold-price-has-the-momentum-to-move-solidly-above-1-800.html')

# %%
#Setting encoding of the HTML page
r.encoding = 'utf-8'

# %%
# Extracting the HTML from the request object
html = r.text

# %%
# Printing the first 500 characters in html
print(html[:500])
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" itemscope itemtype="http://schema.org/Article"><!-- InstanceBegin template="/Templates/media_article_v2.dwt" codeOutsideHTMLIsLocked="false" -->
# 	<head>
#
#
# 				<title>Sentiment shows gold price has the momentum to move solidly above $1,800 | Kitco News</title>
# 				<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
#
# 		   <!-- p

# %%
# Creating a BeautifulSoup object from the HTML
soup = BeautifulSoup(html)
# Getting the text out of the soup
text = soup.get_text()

# %%
#total length
len(text)
# Out:
# 17283

# %%
#having a look at the text
print(text[100:1100])
# Out:
# Make Kitco Your Homepage
#
#
#
#
# Login
#
#
# Sign Up
#
# Refresh Page
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
# Buy/Sell Gold &
# 							Silver Bullion Coins and Bars
#
#
# Online Store
#
#
#
# Buy Gold & Silver
#
#
# Great Deals
#
#
# Gift Ideas
#
#
# Cool and Collectible
#
#
# Gold
#
#
# Gold Coins
#
#
# Gold Bars
#
#
# Silver
#
#
# Silver Coins
#
#
# Silver Rounds
#
#
# Silver Bars
#
#
# Platinum
#
#
# Platinum Coins
#
#
# Platinum Bars
#
#
# Palladium
#
#
# Rhodium
#
#
# Bullion Mints
#
#
# Kitco Pool
#
#
# VaultChain™
#
# GOLD
# SILVER
#
#
#
# Sell Gold & Silver
#
#
# Coins and Bars
#
#
# Rhodium Products
#
#
# Kitco Pool
#
#
# Refining and Scrap
#
# VaultChain™ Gold
# VaultChain™ Silver
#
# Storage Programs
#
# Kitco AllocatedStorage Program
#
# IRA/RSP
# VaultChain™
#
# Refining Services
#
# Jeweler Resources
# Reference Tables
# Refining
#                                                     and Scrap
#
# Institutional and  Wholesale Services
#
#
# Customer Service
#
# Contact Us
# Shipping and Insurance
# Payments andCancellations
# Business Hours
#
# Retail Store Lo

# %%
# Text Cleaning

clean_text= text.replace("n", " ")
clean_text= clean_text.replace("/", " ")       
clean_text= ''.join([c for c in clean_text if c != "'"])

# %%
clean_text
# Out:
# '\n\nSe time t shows gold price has the mome tum to move solidly above $1,800 | Kitco News\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMake Kitco Your Homepage\n\n\n\n\nLogi \n\n\nSig  Up\n\nRefresh Page\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\n\n\n\nBuy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio  Coi s a d Bars\r\n\t\t\t\t\t\n\nO li e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat Deals\n\n\nGift Ideas\n\n\nCool a d Collectible\n\n\nGold\n\n\nGold Coi s\n\n\nGold Bars\n\n\nSilver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\n\nSilver Bars\n\n\nPlati um\n\n\nPlati um Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nRhodium\n\n\nBullio  Mi ts\n\n\nKitco Pool\n\n\nVaultChai ™\n\nGOLD\nSILVER\n\n\n\nSell Gold & Silver\n\n\nCoi s a d Bars\n\n\nRhodium Products\n\n\nKitco Pool\n\n\nRefi i g a d Scrap\n\nVaultChai ™ Gold\nVaultChai ™ Silver\n\nStorage Programs\n\nKitco AllocatedStorage Program\n\nIRA RSP\nVaultChai ™\n\nRefi i g Services\n\nJeweler Resources\nRefere ce Tables\nRefi i g\r\n                                                    a d Scrap\n\nI stitutio al a d  Wholesale Services\n\n\nCustomer Service\n\nCo tact Us\nShippi g a d I sura ce\nPayme ts a dCa cellatio s\nBusi ess Hours\n\nRetail Store Locatio \n\nFeedback\n\nFAQs\n\n\nMy\r\n                                            Kitco Accou t\n\nOpe \r\n                                                    a  Accou t\nActivate\r\n                                                    O li e Profile\nCheck\r\n                                                    Tra sactio  Status\nReset\r\n                                                    Password\n\nPromotio al EmailsSig  Up\n\n\n\n\n\n\n\n\nAll Metal Quotes\n\nAll Metal\r\n\t\t\t\t\t\t\t\tQuotes\n\n\n\nLo do \r\n\t\t\t\t\t\t\t\t\t\t\tFix Prices\nSha ghai Gold Fix\nPrecious Metals Prices Today\n\nGold Price Today\nSilver Price Today\nPlati um Price Today\nPalladium Price Today\n\nPrecious Metals Quotes by Curre cy\nMetals\r\n\t\t\t\t\t\t\t\t\t\t\tFutures\nKitco Silver\nBase Metals\nStrategic Metals\n\nText Quotes\nFree Web Quote Ba  ers\n\n\n\n\n  \n\n\n\nCharts & Data\n\nCharts &\r\n\t\t\t\t\t\t\t\tData\n\n\n\nLive Charts\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\nTech ical Charts\n\nGold\nSilver\nPlati um\nPalladium\n\nFree Charts o  yourWeb\r\n\t\t\t\t\t\t\t\t\t\t\tSite\n\n\nHistorical\r\n\t\t\t\t\t\t\t\t\t\t\tCharts & Data\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\nLo do  Fix Prices\n\nMarket Fu dame tals\n\nGold\nSilver\n\nFree Web Quote Ba  ers\n\n\nI teractive\r\n\t\t\t\t\t\t\t\t\t\t\tCharts\n\n\nPrecious Metals\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\n\nBase Metals\n\nAlumi um\nCopper\nNickel\nLead\nZi c\n\nCurre cy Excha ge Rates\n\nAUD\nBRL\nCAD\nCHF\nCNY\nEUR\nGBP\n\n\nHKD\nINR\nJPY\nMXN\nRUB\nZAR\n\n\n\n\n\n\n\n\n\nCrypto\n\nCrypto Market\n\n\n\nCrypto News\nMarkets\n\nBitcoi \nEthereum\nBi a ce Coi \nXRP\nSola a\nCarda o\nDogecoi \nAvala che\nPolkadot\nShiba I u\nPolygo \n\n\n\n\nChai li k\nU iswap\nNear Protocol\nAxie I fi ity\nThe Sa dbox\nDece trala d\nCosmos\nFa tom\nTheta Network\n\nNewsletters Sig up\nRSS\nAdvertise With Us\n\n\n\n\n\n\nFollow us o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMarkets\n\nMarkets\n\n\n\n\nMarkets\r\n\t\t\t\t\t\t\t\t\t\t\tOverview\n\nDow\n\nNasdaq\n\nS&P\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t500\nNYSE\n\nGold\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tVIX\nMost Active Stocks\n\n\n\nMi i g\n\nGold\n\nSilver\n\nIro \n\nBase\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tMetals\nNo -Ferrous\n\n\n\n\nFutures\n\nMetals\n\nE ergies\n\nGrai s\n\nI dices\n\nSofts\n\nMeats\n\nRates\n\nCurre cies\n\n\n\n\n\n\nForex Major\r\n\t\t\t\t\t\t\t\t\t\t\tRates\n\nCurre cy Co verter\nCurre cy Cross Rates\n\n\n\n\nCryptocurre cies\n\nBitcoi \nEthereum\nLitecoi \nMo ero\nRipple\nDash\nZcash\nPeercoi \nNamecoi \n\n\n\nStocks Gai ers& Losers\n\n\n\n\nKitco Gold\r\n\t\t\t\t\t\t\t ...

# %%
sentence=[]
tokens = nlp(clean_text)
for sent in tokens.sents:
    sentence.append((sent.text.strip()))

# %%
sentence
# Out:
# ['Se time t shows gold price has the mome tum to move solidly above $1,800 | Kitco News\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMake Kitco Your Homepage\n\n\n\n\nLogi \n\n\nSig  Up\n\nRefresh Page\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome',
#  'Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio  Coi s a d Bars\r\n\t\t\t\t\t\n\nO li',
#  'e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat Deals\n\n\nGift Ideas\n\n\nCool a d Collectible\n\n\nGold\n\n\nGold Coi s\n\n\nGold Bars',
#  'Silver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\n\nSilver Bars\n\n\nPlati um\n\n\nPlati um',
#  'Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nRhodium\n\n\nBullio  Mi ts\n\n\nKitco Pool\n\n\nVaultChai ™\n\nGOLD\nSILVER\n\n\n\nSell Gold & Silver\n\n\nCoi s a d Bars\n\n\nRhodium Products\n\n\nKitco Pool\n\n\nRefi',
#  'i g a d Scrap\n\nVaultChai ™ Gold\nVaultChai ™ Silver\n\nStorage Programs\n\nKitco AllocatedStorage Program\n\nIRA RSP\nVaultChai ™',
#  'Refi i g Services\n\nJeweler Resources\nRefere ce Tables',
#  'Refi i g\r\n                                                    a d Scrap\n\nI stitutio al a d  Wholesale Services\n\n\nCustomer Service\n\nCo tact Us\nShippi g',
#  'a d I sura ce\nPayme ts a dCa cellatio s\nBusi ess Hours\n\nRetail Store Locatio \n\nFeedback\n\nFAQs\n\n\nMy\r\n                                            Kitco Accou t\n\nOpe \r\n                                                    a  Accou t\nActivate\r\n                                                    O li e Profile\nCheck\r\n                                                    Tra sactio  Status\nReset\r\n                                                    Password\n\nPromotio al EmailsSig  Up\n\n\n\n\n\n\n\n\nAll Metal Quotes\n\nAll Metal\r\n\t\t\t\t\t\t\t\tQuotes\n\n\n\nLo do \r\n\t\t\t\t\t\t\t\t\t\t\tFix Prices\nSha ghai',
#  'Gold Fix\nPrecious Metals Prices Today\n\nGold Price',
#  'Today\nSilver Price Today\nPlati um Price Today\nPalladium Price Today\n\nPrecious Metals Quotes by Curre cy\nMetals\r\n\t\t\t\t\t\t\t\t\t\t\tFutures\nKitco Silver\nBase Metals\nStrategic Metals\n\nText Quotes\nFree Web',
#  'Quote Ba  ers',
#  'Charts & Data\n\nCharts &\r\n\t\t\t\t\t\t\t\tData\n\n\n\nLive Charts\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\nTech ical Charts\n\nGold\nSilver\nPlati um\nPalladium\n\nFree Charts o  yourWeb\r\n\t\t\t\t\t\t\t\t\t\t\tSite\n\n\nHistorical\r\n\t\t\t\t\t\t\t\t\t\t\tCharts & Data\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\nLo do  Fix Prices\n\nMarket Fu',
#  'dame tals\n\nGold\nSilver\n\nFree Web',
#  'Quote Ba  ers\n\n\nI teractive\r\n\t\t\t\t\t\t\t\t\t\t\tCharts\n\n\nPrecious Metals\n\nGold\nSilver\nPlati um',
#  'Palladium\nRhodium\n\n\n\nBase Metals\n\nAlumi um\nCopper\nNickel\nLead\nZi c\n\nCurre cy Excha ge Rates\n\nAUD\nBRL\nCAD\nCHF\nCNY\nEUR\nGBP\n\n\nHKD\nINR\nJPY\nMXN\nRUB\nZAR\n\n\n\n\n\n\n\n\n\nCrypto\n\nCrypto Market\n\n\n\nCrypto News\nMarkets\n\nBitcoi \nEthereum\nBi a ce Coi \nXRP\nSola a\nCarda o\nDogecoi \nAvala',
#  'che\nPolkadot',
#  'Shiba',
#  'I u\nPolygo \n\n\n\n\nChai li k\nU iswap\nNear Protocol',
#  'Axie I fi',
#  'ity\nThe Sa dbox\nDece trala',
#  'd\nCosmos\nFa tom\nTheta Network\n\nNewsletters Sig up\nRSS\nAdvertise With Us\n\n\n\n\n\n\nFollow us o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMarkets\n\nMarkets\n\n\n\n\nMarkets\r\n\t\t\t\t\t\t\t\t\t\t\tOverview\n\nDow\n\nNasdaq\n\nS&P\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t500\nNYSE\n\nGold\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tVIX\nMost Active Stocks\n\n\n\nMi',
#  'i g\n\nGold\n\nSilver\n\nIro \n\nBase\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tMetals\nNo -Ferrous\n\n\n\n\nFutures\n\nMetals\n\nE ergies\n\nGrai s\n\nI dices\n\nSofts\n\nMeats\n\nRates\n\nCurre cies\n\n\n\n\n\n\nForex Major\r\n\t\t\t\t\t\t\t\t\t\t\tRates\n\nCurre cy Co verter\nCurre cy Cross Rates\n\n\n\n\nCryptocurre cies',
#  'Bitcoi \nEthereum\nLitecoi \nMo ero\nRipple\nDash\nZcash\nPeercoi \nNamecoi \n\n\n\nStocks Gai ers& Losers\n\n\n\n\nKitco Gold\r\n\t\t\t\t\t\t\t\t\t\t\tI dex\n\n\nMetals\n\n\nSearch Stocks',
#  'News\n\nNews\n\n\n\nLatest News\n\nGold News\nAM-PM Rou dup\nEco omic News\n\nExclusive Features\n\nGold Survey\nGold Outlook\nKitco Focus\n\n\nVideo News\nOff',
#  'The Wire\nMore News\n\n\n\n\nCrypto News\nMi i g News\nSearch News\n\n\nNewsletters Sig up\nAbout Kitco NEWS\nRSS Feed\nAdvertise With Us\n\n\n\n\n\n\n\nFollow us',
#  'o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\nComme taries\n\nComme taries\n\n\n\nA alysis',
#  'Jim Wyckoff\nA alytical Charts\nWhere Are the Stops\nForex Charts\n\n\nComme tators Cor er\nCo tributed Comme taries\nCPM Group\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\nKitco Select',
#  'Jo atha  Da Silva\nGary Wag',
#  'er\nTodd Bubba Horwitz\nFra k E. Holmes\nPhillip Streible\nMickey Fulp\nDavid Erfle',
#  'Mi i',
#  'g',
#  'Mi',
#  'i g',
#  'Mi i g News\nVideo News\nPodcast\nLatest Press  Releases\nMi',
#  'i g by Sector\n\nGold\nSilver\nIro \nBase-Metals\nNo -Ferrous\n\n\n\nMetals Futures\nMi',
#  'i g Stock I dices',
#  'XAU\nNYSE Arca Gold BUGS\nJSE Gold\nTSX Gold\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\n\n\n\n\nFollow us o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\nGold Forum\n\nGold Forum\n\n\n\nGold Forum\n\nLogi \n\nFAQ\nTodays\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tPosts\nMembership\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tRules\n\n\n\n\n\n  \n\n\n\nMobile Apps\n\nMobile Apps\n\n\n\nKitco Applicatio s\n\n\nOur applicatio s are powerful, easy-to-use a d available o  all devices.',
#  'Gold Live!',
#  'iOS\n\nGold Live!',
#  'A droid\n\nGold Live!',
#  'A droid Widget\nGold Live!',
#  'Desktop\nWi dows\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tTaskbar\n\n\n\nMarket Alerts\n\n\nFree tool to help with golda d silver buyi g a d\r\n\t\t\t\t\t\t\t\t\t\t\t\tselli',
#  'g decisio s\n\nMy Alerts Accou t\nOpe  a  Accou t\n\nScrapIt!',
#  'Real-time gold scrap value calculator for professio als\r\n\t\t\t\t\t\t\t\t\t\t\t\n\n\niPho e •\r\n\t\t\t\t\t\t\t\t\t\t\tA droid •\r\n\t\t\t\t\t\t\t\t\t\t\tWeb\n\n\nMetaly x\n\n\n\nCalculate precious metaldime',
#  'sio s, weights a d\r\n\t\t\t\t\t\t\t\t\t\t\t\tpurity\n\n\niPho e •\r\n\t\t\t\t\t\t\t\t\t\t\tA droid\n\n\n\n\n\n\n  \n\n\n\nJeweler  Resources\n\nJeweler\r\n\t\t\t\t\t\t\t\tResources\n\n\n\nRefi i g',
#  'Services\nRefere ce Tables\n\nMelti',
#  'g Poi ts\nDWT Oz Gram Co versio',
#  'Gauge',
#  'I ch mm\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tCo versio \nWeight Compariso \n\n\nMetaly x\n\n\nCalculate precious metal dime',
#  'sio s, weights a d purity\r\n\t\t\t\t\t\t\t\t\t\t\t\n\n\nScrapIt!\n\n\nReal-time gold scrap value calculator for professio als\r\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n  \n\n\n\nAbout\n\nAbout\n\n\n\nAbout Kitco\n\nWho We\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tAre\nWhat We Do\nCareers',
#  'Media Ce ter\nCo tact Us\nFeedback\n\nAdvertise With Us\nSitemap\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n Favorites:\n\n\n\n\n\n\n\n\n\n\n\n\nEDIT\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nO li e',
#  'Store\n\n\n\nBuy from Kitco\n\n\nGreat Deals!',
#  'Cool a d Collectible\nBu dle Products\nGold Products\nSilver Products\nPlati um Products\nPalladium Products\nRhodium Products\nAccessories\nKitco Pool\n\n\n\n\nVaultChai  ™\n\n\nGOLD\nSILVER\n\n\n\n\nStorage Programs',
#  'Kitco Allocated Storage Program\nIRA RSP\nRoyal Ca adia  Mi t Prestige Accou t\nVaultChai ™\n\n\n\n\nSell to Kitco\n\n\nCoi s a d Bars\nRhodium Products\nKitco Pool\nRefi',
#  'i g a d Scrap\nVaultChai',
#  '™ Gold\nVaultChai ™ Silver\n\n\n\n\nRefi i g Services\n\n\nJeweler Resources',
#  'Refere ce Tables',
#  'Refi i g a d Scrap\n\n\n\nI stitutio al a d Wholesale Services\n\nCustomer Service\n\n\nCo tact Us\nShippi g',
#  'a d I sura ce\nPayme ts a dCa cellatio s\nBusi ess Hours\nRetail Store Locatio \nFeedback\nFAQs',
#  'My Kitco Accou t\n\n\nOpe  a  Accou t\nActivate',
#  'O li e Profile\nCheck Tra sactio  Status\nReset Password\n\n\n\n\nPromotio al Emails Sig  Up\n\n\n\n\n  \n\n\n\nAll Metal Quotes\n\n\nLo do  Fix Prices\nPrecious Metals Quotes by',
#  'Curre cy\nMetals Futures\nKitco Silver\nBase Metals\nStrategic Metals\n\nText Quotes\nFree Web',
#  'Quote Ba  ers\n\n\n\n  \n\n\n\nCharts & Data\n\n\n\nLive Charts\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\n\n\nTech ical Charts\n\n\nGold\nSilver',
#  'Plati um\nPalladium\n\n\n\nFree Charts o  your Web Site\n\nHistorical Charts & Data\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\nLo do  Fix Prices\n\n\n\n\nMarket Fu dame tals\n\n\nGold\nSilver\n\n\n\nFree Web Quote Ba  ers\n\nI',
#  'teractive Charts\n\n\nPrecious Metals\nGold\nSilver\nPlati um\nPalladium\nRhodium\nBase Metals\nAlumi um\nCopper\nNickel\nLead\nZi c\n\n\nCurre cy Excha ge Rates\n\n\nAUD\nHKD\nBRL\nINR\nCAD\nJPY\nCHF\nMXN\nCNY\nRUB\nEUR\nZAR\nGBP\n\n\n\n\n\n\n\n\n\n\nCrypto Market\n\n\nCrypto News\n\nMarkets\n\n\nBitcoi \nEthereum\nBi a ce Coi \nXRP\nSola a\nCarda o\nDogecoi \nAvala',
#  'che\nPolkadot',
#  'Shiba',
#  'I u\nPolygo \nChai li k\nU iswap\nNear Protocol',
#  'Axie I fi',
#  'ity\nThe Sa dbox\nDece trala',
#  'd\nCosmos\nFa tom\nTheta Network\n\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\n  \n\n\n\nMarkets\n\n\n\nMarket Overview\n\n\nDow\nNasdaq\nS&P 500\nNYSE\nGold VIX\nMost Active Stocks\n\n\n\n\nForex Major Rates\n\n\nCurre cy Co verter\nCurre cy Cross Rates\n\n\n\nKitco Gold',
#  'I dex',
#  'Mi',
#  'i g\n\n\nGold\nSilver\nIro \nBase Metals\nNo -Ferrous\n\n\n\nBitcoi \nMetals\n\nFutures\n\n\nMetals\nE ergies\nGrai s\nI dices\nSofts\nMeats\nRates\nCurre cies\n\n\n\nStocks Gai ers & Losers',
#  'Search Stocks\n\n\n\n  \n\n\n\nNews\n\n\n\nLatest News\n\n\nGold News\nAM-PM Rou dup\nEco omic News\n\n\n\n\nExclusive Features\n\n\nGold Survey\nGold Outlook\nKitco Focus\n\n\n\nVideo  ews\nOff The Wire\nMore News\nCrypto News',
#  'Mi i g News\nSearch News\nNewsletters Sig up\nAbout Kitco NEWS\nRSS Feed\nAdvertise With Us\n\n\n\n  \n\n\n\nComme taries\n\n\n\nA alysis\n\n\nJim Wyckoff\nA alytical Charts\nWhere Are the Stops\nForex Charts\n\n\n\nComme tators Cor er\nCo tributed Comme taries\nCPM Group\nNewsletters Sig up\nRSS Feed\nAdvertise With Us',
#  'Kitco Select\n\n\nJo atha  Da Silva\nGary Wag',
#  'er\nTodd Bubba Horwitz\nFra k E. Holmes\nPhillip Streible\nMickey Fulp\nDavid Erfle',
#  'Mi i g\n\n\nMi',
#  'i g News\nVideo News\nPodcast\nLatest Press Releases',
#  'Mi',
#  'i g by Sector\n\n\nGold\nSilver\nIro \nBase-Metals',
#  'No -Ferrous\n\n\n\n\nMi i g Stock I dices',
#  'XAU\nNYSE Arca Gold BUGS\nJSE Gold\nTSX Gold\n\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\n  \n\n\n\nGold Forum\n\n\n\nGold Forum\n\n\nLogi \nFAQ\nTodays Posts\nMembership Rules\n\n\n\n\n\n\n  \n\n\n\nMobile Apps\n\n\n\nKcast Gold Live\n\n\nFree live gold price, charts,  ews\niPho e\niPad\nA droid\nA droid Widget\nWi dows Pho e 7\nBlackberry\nBlackberry Playbook\nWi dows Taskbar\nDesktop for Mac, PC or Wi dows\n\n\n\n\nMarket Alerts\n\n\nFree tool for maki g buyi g a d selli',
#  'g decisio s\nMy Alerts Accou t\nOpe  a  Accou t\n\n\n\n\nScrapIt!',
#  'Real-time gold scrap value calculator for professio als\niPho e\nA droid\nWeb\n\n\n\n\nMetaly x\n\n\nCalculate precious metal dime sio s, weights a d purity\niPho e\nBlackberry\nA droid\n\n\n\n\n\n\n  \n\n\n\nJeweler Resources\n\n\nRefi',
#  'i g Services\n\nRefere ce Tables\n\n\nMelti',
#  'g Poi',
#  'ts\nDWT Oz Gram Co versio \nGauge',
#  'I ch mm',
#  'Co versio \nWeight Compariso \n\n\n\n\nMetaly',
#  'x\n\n\nScrapIt!\n\n\n\n\n  \n\n\n\nAbout\n\n\n\nAbout Kitco\n\n\nWho We Are\nWhat We Do\nCareers\nMedia Ce ter\nCo tact Us\nFeedback',
#  'Advertise With Us\nSitemap\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\r\n\t\t\t\tYou are i',
#  'Home >',
#  'News >',
#  'Exclusive Features >',
#  'Gold Survey\n\n\n\n\n\n\n\n\n\n\nGold Survey\n\n\n\n\nSe time t shows gold price has the mome tum to move solidly above $1,800\n\n\n\n\n\n\n\n\nNeils Christe se \n\n\n\n\n\n\nFriday December 02, 2022 13:48\n\n\n\n\n\n\n\nKitco News\n\nShare this article:',
#  'Editors Note: With so much market volatility, stay o  top of daily  ews!',
#  'Get caught up i  mi utes with our speedy summary of todays must-read  ews a d expert opi io s. Sig  up here!',
#  '(Kitco News) -',
#  'A stro g start to  December as prices e d the week above $1,800 a d  ear their highest level i   more tha  three mo ths is creati g sig ifica t bullish se time t',
#  'i  the  marketplace; however, the questio  remai s if se time t will be e ough to bri g  i vestors off the sideli es.',
#  'The latest Kitco News  Weekly Gold Survey shows that Wall Street a alysts a d Mai  Street retail',
#  'i vestors are sig ifica tly bullish o  gold i  the  ear term as the market sees  solid tech ical bullish mome tum.',
#  'The rally i  gold started  Wed esday whe  Federal Reserve Chair Jerome Powell said that it could be  appropriate for the U.S. ce tral',
#  'ba k',
#  'to slow its pace of tighte i',
#  'g i   December.',
#  'At the same time,  a alysts have also said that growi g recessio  fears are also providi g a fresh  safe-have  boost to gold.',
#  'Coli  Cieszy ski, chief  market strategist at SIA Wealth Ma ageme t, said that he remai s bullish o   gold eve  if risi g',
#  'i terest rates co ti ue to support the U.S. dollar.',
#  '"I vestors are  starti g to realize that gold is still a  importa t defe sive asset," he  said.',
#  '"It co ti ues to play its role as a store of value."',
#  'Adam Butto , head of  curre cy strategy at Forexlive.com, said that gold is also be efiti g from  positive seaso al factors as dema d picks up ahead of the holidays.',
#  '"The seaso al tre d  of gold-buyi g i  December kicked i  from the first day of the mo th.',
#  'With the  Fed tilti g a d the U.S. dollar slidi g, the stars are alig ed for gold,"  he said.',
#  'This week, 18 Wall  Street a alysts participated i  the Kitco News Gold Survey.',
#  'Amo g the  participa ts, 12 a alysts, or 67%, were bullish o  gold i  the  ear term a d  six a alysts, or 33%, were bearish for  ext week.',
#  'There were  o  eutral votes  i  this weeks survey.',
#  'Mea while, 1,018 votes  were cast i  a  o li e Mai  Street poll.',
#  'Of these, 715 respo de ts, or 70%,  looked for gold to rise  ext week.',
#  'A other 188, or 18%, said it would be lower,  while 115 voters, or 11%, were  eutral i  the  ear term.',
#  'Wall Street\n Bullish    \n Bearish    \n Neutral   \n\nVS\n\nMai  Street\n Bullish    \n Bearish    \n Neutral   \n\n\nThe solidly optimistic  outlook comes as gold prices look to e d the week with a 2% gai , with February  gold futures last tradi g at $1,809 a  ou ce.',
#  'Eve  a stro ger-tha -expected  November employme t report with stro g wage growth has  ot bee  e ough to  dampe  golds  ew mome tum.',
#  'Friday, the Bureau of  Labor Statistics said 263,000 jobs were created i  November; eco omists  expected job gai s of 200,000.',
#  'At the same time, wages i creased 5.1% for the  year, well above expectatio s. \nDari  Newsom, se ior  market a alyst at Barchart, said that  ext week could be exciti g for the  precious metal as the curre t rally could be see  as a tech ical blowoff top;  however, he added mome tum is clearly o  the bullish side.',
#  '"Its markets like  gold that lead to dri ki g problems for tech ical a alysts," he said.',
#  '"Give  weekly stochastics have  ot clearly moved above the overbought  level of 80%, Feb gold looks to have time a d space to move higher  ext week.',
#  'However, a d heres where thi gs get fu , its target area is betwee  $1,807.20  (with this weeks high already $1,818.70) a d $1,861.20."',
#  'However,  ot all  a alysts are bullish o  gold, at least i  the  ear-term.',
#  'Adria  Day, preside t  of Adria  Day Asset Ma ageme t, said that while he remai s a lo g-term gold  bull, he does see gold prices dippi g  ext week.',
#  '',
#  'GLD positio',
#  'i g itself for future growth with seco d custodia  for its gold\n\n\n"We will likely see  some follow-through to the decli e o  the latest U.S. jobs report, which showed  more  ew jobs tha  estimated, as well as a  atural correctio  to a sharp weekly  rally," he said.',
#  '"But after that, a recovery, as more market  participa ts come to appreciate that the Federal Reserve (a d other ce tral  ba ks, particularly the ECB a d BoE) simply will be u able to achieve their  i flatio  targets without provoki g a serious recessio .',
#  'Sig s of a  impe di g  recessio  are gatheri g." \nMarc Cha dler, ma agi g  director of Ba  ockbur  Global Forex, said that he is bearish o  gold  ext week  as markets are too optimistic o  Powells supposed dovish sta ce.',
#  'He added that risi g  wages i  Novembers employme t report show that the Federal Reserve still has  to deal with a growi',
#  'g i flatio  problem.',
#  '"Gold the  looks  likely to reject the false break above the 200-day movi g average.',
#  'I look for  $1765 a d maybe $1750 before the FOMC meeti',
#  'g i  the middle of the mo th,"  he said.',
#  'By Neils Christe se \n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \t\t\t\tFor Kitco News\n\nFollow  eils_C\n\n\n\n christe se @kitco.com\n\n\n\n\nwww.kitco.com',
#  'Disclaimer:',
#  'The views expressed i  this article are those of the author a d may  ot reflect those of Kitco Metals I c.',
#  'The author has made every effort to e sure accuracy of i formatio  provided; however,  either Kitco Metals I c.  or the author ca  guara tee such accuracy.',
#  'This article is strictly for i formatio al purposes o ly.',
#  'It is  ot a solicitatio  to make a y excha',
#  'ge i  commodities, securities or other fi a cial i strume ts.',
#  'Kitco Metals I c. a d the author of this article do  ot accept culpability for losses a d  or damages arisi g from the use of this publicatio .',
#  '',
#  'ew\n\n\n\n\n\nTodays Crypto Markets\n\n\n\n\n\nBitcoi \n\n\n\n\n\n\n\n\n\n\n\nEthereum\n\n\n\n\n\n\n\n\n\n\n\nXRP\n\n\n\n\n\n\n\n\n\nMore crypto markets a d  ews...\n\n\n\n\n\n\n Latest Articles\n\n\nNews\n\nVideo News\n\nComme taries\n\n\n\n\n\n\n\nGold is better portfolio diversifier tha  bitcoi  -Goldma  Sachs\n\nDec 12, 2022 02:05PM\n\n\n\n\n\n\n\nMetalla to acquire royalties',
#  'o  Barrick Golds Lama project',
#  'i  Arge ti a\n\nDec 12, 2022 01:58PM\n\n\n\n\n\n\n\nHollywood could fu d movies usi g crypto, NFTs - James Mackie a d Matt Hooki',
#  'gs\n\nDec 12, 2022 01:41PM\n\n\n\n\n\n\n\nAmerica s expected wa i',
#  'g i flatio  pressures, risi g',
#  'i comes i  November\n\nDec 12, 2022',
#  '01:33PM\n\n\n\n\n\n\n\nFirst Mi i g sells its Goldlu d NSR royalty to Sprott for C$9.5 millio \n\nDec 12, 2022 01:28PM\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMo day Charts for Gold, Silver a d Plati um a d Palladium, December 12',
#  'Dec 12, 2022 10:09AM\n\n\n\n\n\n\n\nEyes o  FOMC - Bulls still i  co trol\n\nDec 12, 2022 09:15AM\n\n\n\n\n\n\n\nWhere are the stops?',
#  'Mo day, December 12, gold a d silver\n\nDec 12, 2022 07:59AM\n\n\n\n\n\n\n\nCould gold’s 200-day movi g average become a tech ical level of support?\n\nDec 10, 2022 04:56AM\n\n\n\n\n\n\n\nThe Metals, Mo ey, a d Markets Weekly Dec.9, 2022: J is for Jo esi \n\nDec  9, 2022 05:03PM\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n Precious Metal Charts\n\n\nGold\nSilver\nPlati um\nPalladium\n\n\n\n24h\n30D\n60D\n6M\n1Y\n\n\xa0\nI teractive Chart\n\n\n\n\n\n Follow Kitco News\n\nTweets by KitcoNewsNOW\n\n\n\n\n\n\n\n\n3460379\n2\n  www.kitco et.com \n\n\n\n\n\n\nKitco\nHome\nAll Metal Quotes\nCharts & Data\nMarkets\nNews\nComme taries',
#  'Mi i g\nCo  ect\nAbout Us\nKitco Media\nCareers\nCo tact Us\nAdvertise With Us\n\n\nTools\nKitco Gold',
#  'I dex\nI teractive Gold Chart\nBitcoi',
#  'i  USD\nCurre cy Co verter\nScrapIt!',
#  'Mobile Applicatio \nSite Map\nO li',
#  'e Store\n\n Be I formed of our\r\n\t\t\t\t\tspecial offers, alerts a d  ews.',
#  'sig  up\n\n\n\n We appreciate your\r\n\t\t\t\t\tfeedback.',
#  'Submit\r\n\t\t\t\t\t\n\n\n\n\nVisit Kitco\r\n\t\t\t\t\tMobile Apps\n\n\n\n\n\n\r\n\t\t\t\t\tHow ca  we help you?',
#  '1 877 775-4826\n\n\n\n\n\n\n\n\n\n\n\n\r\n\t\t\t\t\tDrop us a li e i fo@kitco.com',
#  'Website Terms of Use |\nTerms & Co ditio s\nPrivacy Policy']

# %%
# Printing length of sentences

print(len(sentence))
# Out:
# 169

# %%
# Looking at the random sentence to verify
print(sentence[2])
# Out:
# e Store
#
#
#
# Buy Gold & Silver
#
#
# Great Deals
#
#
# Gift Ideas
#
#
# Cool a d Collectible
#
#
# Gold
#
#
# Gold Coi s
#
#
# Gold Bars

# %% [markdown]
# ## Part 2: Sentiment Analysis with Textblob

# %%
textblob_sentiment=[]
for s in sentence:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob.head()
# Out:
#                                             Sentence  Polarity  Subjectivity
# 0  Se time t shows gold price has the mome tum to...  0.000000      0.100000
# 1  Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio...  0.000000      0.000000
# 2  e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat De...  0.216667      0.733333
# 3  Silver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\...  0.000000      0.000000
# 4  Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nR...  0.000000      0.000000

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      169 non-null    object
#  1   Polarity      169 non-null    float64
#  2   Subjectivity  169 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.1+ KB

# %%
# Analyzing polarity using visuals

sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Polarity (Textblob)')

# %% [markdown]
# Due to some reason around half the sentences have zero polarity. Maybe, its because of the dact they are neutral. A few sentences are highly positive and a few are negative.

# %%
# Analyzing subjectivity using visuals

sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Subjectivity (Textblob)')

# %% [markdown]
# The values of subjectivity also very with few sentences being highly subjective and a majority of sentences being less subjective.

# %% [markdown]
# ## Part 3: Sentiment Analysis with Pattern

# %%
pattern_sentiment=[]
for s in sentence:
    res= sentiment(s)
    c= res[0]
    d= res[1]
    pattern_sentiment.append([s,c,d])

# %%
pattern_sentiment[1]
# Out:
# ['Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio  Coi s a d Bars\r\n\t\t\t\t\t\n\nO li',
#  0.0,
#  0.0]

# %%
df_pattern = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_pattern.head()
# Out:
#                                             Sentence  Polarity  Subjectivity
# 0  Se time t shows gold price has the mome tum to...  0.000000      0.100000
# 1  Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio...  0.000000      0.000000
# 2  e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat De...  0.216667      0.733333
# 3  Silver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\...  0.000000      0.000000
# 4  Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nR...  0.000000      0.000000

# %%
df_pattern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      169 non-null    object
#  1   Polarity      169 non-null    float64
#  2   Subjectivity  169 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.1+ KB

# %%
# Plotting the scores

sns.displot(df_pattern["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Pattern)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Polarity (Pattern)')

# %%
sns.displot(df_pattern["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Pattern)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Subjectivity (Pattern)')

# %% [markdown]
# Similar data distribution can be seen.

# %% [markdown]
# ## Part 4: Word frequency and Word Cloud

# %%
# Creating the nltk tokenizer and Tokenizing text

tokens = nltk.tokenize.word_tokenize(clean_text)

# %%
len(tokens)
# Out:
# 3078

# %%
print(tokens[0:10])
# Out:
# ['Se', 'time', 't', 'shows', 'gold', 'price', 'has', 'the', 'mome', 'tum']

# %%
# Converting to lower cases for uniformality

words = []
# Looping through the tokens and make them lower case
for word in tokens:
    words.append(word.lower())

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
words_new = []
# Appending to words_new all words that are in words but not in stopwords
for word in words:
    if word not in stopwords:
        words_new.append(word)

# %%
len(words_new)
# Out:
# 2372

# %%
print(words_new[0:10])
# Out:
# ['se', 'time', 'shows', 'gold', 'price', 'mome', 'tum', 'move', 'solidly', '$']

# %%
# The frequency distribution of the words

freq_dist = nltk.FreqDist(words_new)

# %%
# Frequency Distribution Plot

plt.subplots(figsize=(16,10))
freq_dist.plot(20)

# %%
# Converting into string

res=' '.join([i for i in words_new if not i.isdigit()])

# %%
# Plotting Word Cloud

plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(res)
plt.imshow(wordcloud)
plt.title('NEWS ARTICLE (100 words)')
plt.axis('off')
plt.show()
